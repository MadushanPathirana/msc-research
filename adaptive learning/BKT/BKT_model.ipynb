# %%
import numpy as np
import pandas as pd
from pyBKT.models import Model
import matplotlib.pyplot as plt

# %%
model = Model(seed = 42, num_fits = 1)
model.fit('bkt_data.csv')

# %%
bkt_data=pd.read_csv('bkt_data.csv')

# %%
training_rmse = model.evaluate(data = bkt_data)
training_auc = model.evaluate(data_path = 'bkt_data.csv', metric = 'auc')
print("Training RMSE: %f" % training_rmse)
print("Training AUC: %f" % training_auc)
# Out:
# Training RMSE: 0.387527
# Training AUC: 0.709548

# %%
model.evaluate(data_path = 'bkt_data.csv', metric = 'accuracy')
# Out:
# 0.7954110898661568

# %%
reds_df = model.predict(data_path = 'bkt_data.csv')

# %%
reds_df
# Out:
#       Unnamed: 0                                        KC(Default)  \
# 42            42  Identify identity, conditional, and inconsiste...
# 266          266  Identify identity, conditional, and inconsiste...
# 352          352  Identify identity, conditional, and inconsiste...
# 395          395  Identify identity, conditional, and inconsiste...
# 472          472  Solve equations in one variable algebraically,...
# ...          ...                                                ...
# 686          686  Solve equations in one variable algebraically,...
# 824          824  Solve equations in one variable algebraically,...
# 852          852  Solve equations in one variable algebraically,...
# 937          937  Solve equations in one variable algebraically,...
# 1003        1003  Solve equations in one variable algebraically,...
#
#                               Problem Name  \
# 42    26ed808c-f969-4b07-917d-54a0b8b2e287
# 266   bd27b05c-b70a-4e9a-8ecc-c00aaa9fe05d
# 352   d56f8539-f441-4a0b-98b1-ccba911d04e7
# 395   e2ff2fa9-3212-4062-9ff9-80a26d59e9b7
# 472   16a90996-91ac-449e-b567-3ccacb681d62
# ...                                    ...
# 686   b6e63771-16a8-492d-b88a-945f1d4aacad
# 824   3d98fa83-6209-401d-9bc6-aa3ca8853253
# 852   5dff4e3f-32c2-43c2-86c1-b0635653f503
# 937   9a7e5f13-fc1e-4fe1-9950-4e4a9ef2d700
# 1003  d08b3448-c80b-4483-83d7-ec42d5c3b035
#
#                                    user_id  Corrects  Correct First Attempt  \
# 42    00bc4ffd-824f-44be-a2a4-00c226379f1c         0                      0
# 266   00bc4ffd-824f-44be-a2a4-00c226379f1c         1                      1
# 352   00bc4ffd-824f-44be-a2a4-00c226379f1c         1                      1
# 395   00bc4ffd-824f-44be-a2a4-00c226379f1c         1                      1
# 472   00bc4ffd-824f-44be-a2a4-00c226379f1c         1                      1
# ...                                    ...       ...                    ...
# 686   f4a1ad07-b43d-4682-ac9b-b2919c8b145d         1                      1
# 824   f4a1ad07-b43d-4682-ac9b-b2919c8b145d         1                      1
# 852   f4a1ad07-b43d-4682-ac9b-b2919c8b145d         1                      1
# 937   f4a1ad07-b43d-4682-ac9b-b2919c8b145d         1                      1
# 1003  f4a1ad07-b43d-4682-ac9b-b2919c8b145d         1                      1
#
#       correct_predictions  state_predictions
# 42                0.70530            0.91660
# 266               0.67379            0.82620
# 352               0.69969            0.90050
# 395               0.71525            0.94514
# 472               0.87456            0.95125
# ...                   ...                ...
# 686               0.88469            1.00000
# 824               0.91050            0.86047
# 852               0.91799            0.89222
# 937               0.92393            0.91743
# 1003              0.92858            0.93715
#
# [1046 rows x 8 columns]

# %%
model.params()
# Out:
#                                                                      value
# skill                                              param   class
# Identify identity, conditional, and inconsisten... prior   default 0.91660
#                                                    learns  default 0.00011
#                                                    guesses default 0.38581
#                                                    slips   default 0.26563
#                                                    forgets default 0.00000
# Solve equations in one variable algebraically, ... prior   default 0.95125
#                                                    learns  default 0.99873
#                                                    guesses default 0.67686
#                                                    slips   default 0.11531
#                                                    forgets default 0.00000
# Solve equations in one variable algebraically, ... prior   default 0.86047
#                                                    learns  default 0.00612
#                                                    guesses default 0.70763
#                                                    slips   default 0.05660
#                                                    forgets default 0.00000
# Identify constants and variables                   prior   default 0.82357
#                                                    learns  default 0.25009
#                                                    guesses default 0.63446
#                                                    slips   default 0.36345
#                                                    forgets default 0.00000
# Perform calculations using order of operations     prior   default 0.88265
#                                                    learns  default 0.00761
#                                                    guesses default 0.78844
#                                                    slips   default 0.19845
#                                                    forgets default 0.00000
# Simplify algebraic expressions                     prior   default 0.24651
#                                                    learns  default 0.28489
#                                                    guesses default 0.99926
#                                                    slips   default 0.38065
#                                                    forgets default 0.00000
# Use the following properties of real numbers: c... prior   default 0.00222
#                                                    learns  default 0.97029
#                                                    guesses default 1.00000
#                                                    slips   default 0.47748
#                                                    forgets default 0.00000
