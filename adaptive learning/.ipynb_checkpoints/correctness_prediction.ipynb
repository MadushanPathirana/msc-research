# %%
import pandas as pd

# %%
df=pd.read_csv('test_goal.csv').drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#                                    user_id
# 0     001a31f0-5c4c-4e34-8c92-fcb321265f27  \
# 1     001a31f0-5c4c-4e34-8c92-fcb321265f27
# 2     001a31f0-5c4c-4e34-8c92-fcb321265f27
# 3     001a31f0-5c4c-4e34-8c92-fcb321265f27
# 4     001a31f0-5c4c-4e34-8c92-fcb321265f27
# ...                                    ...
# 2728  fe635bd6-3f6b-48e8-990c-c6eb55e68efe
# 2729  fe635bd6-3f6b-48e8-990c-c6eb55e68efe
# 2730  fe635bd6-3f6b-48e8-990c-c6eb55e68efe
# 2731  fe635bd6-3f6b-48e8-990c-c6eb55e68efe
# 2732  fe635bd6-3f6b-48e8-990c-c6eb55e68efe
#
#                              learning_objective_name
# 0     Locate local and absolute extrema from a graph  \
# 1                            Locate absolute extrema
# 2           Locate critical points using derivatives
# 3               Understand the extreme value theorem
# 4               Understand the extreme value theorem
# ...                                              ...
# 2728                         Locate absolute extrema
# ...
