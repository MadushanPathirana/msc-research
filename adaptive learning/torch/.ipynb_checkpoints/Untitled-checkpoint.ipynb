# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
from scipy import stats
np.random.seed(0)
import pandas as pd
import seaborn as sns

# %%
def meanFunc(x,k,l):
    mean=1/(1+np.exp((k-x)/l))   
    
    return mean

# %%
y = np.array([0.25, 0.2365622342, 0.15630337, 0.6584035078, 0.9819810819, 1.0 ])
x=np.arange(1,len(y)+1)

# %%
popt, pcov = curve_fit(meanFunc, x, y)

# %%
popt
# Out:
# array([3.59960588, 0.64853925])

# %%
yModel=(meanFunc(x,*popt))

# %%
def squared_exponential_kernel(x1, x2, sigma_f=1.0, l=1.0):
    """
    Squared-exponential kernel function.
    
    :param x1: array-like of shape (n_samples_X, n_features)
    :param x2: array-like of shape (n_samples_Y, n_features)
    :param sigma_f: float, default=1.0
        Signal variance.
    :param l: float or array-like of shape (n_features,), default=1.0
        Length scale(s).
    :return: ndarray of shape (n_samples_X, n_samples_Y)
        Kernel k(X, Y).
    """
    sqdist = np.sum(x1**2, 1).reshape(-1, 1) + np.sum(x2**2, 1) - 2 * np.dot(x1, x2.T)
    return sigma_f**2 * np.exp(-0.5*sqdist / l**2 )

# %%
plt.plot(y,c='navy',label='observed')
plt.plot(yModel,'g--',label='model')
plt.legend();

# %% [markdown]
# def multivariateNormal(x,k,l,L,sigma_f):
#     x1=y
#     x2=y
#     mean=1/(1+np.exp((round(k)-x)/l))
#     x1_sq = np.sum(x1**2)
#     x2_sq = np.sum(x2**2)
#     sqdist = x1_sq + x2_sq - 2 * np.dot(x1.T, x2)
#     cov=sigma_f**2 * np.exp(-0.5*sqdist / L**2 )
#     results=stats.multivariate_normal.rvs(mean,cov=cov, size=1,random_state=6).T
#     return results
# popt, pcov = curve_fit(multivariateNormal, x, y,bounds=([0,0,-3,-3], [len(x),1,2,2]))
# popt

# %%
def squared_exponential_kernel2(X1, X2, l=1.0, sigma_f=1.0):
    """
    Computes the squared exponential kernel between two sets of points.
    
    Parameters:
        X1: numpy array of shape (n1, d)
            The first set of points.
        X2: numpy array of shape (n2, d)
            The second set of points.
        l: float, optional (default=1.0)
            The length scale parameter.
        sigma_f: float, optional (default=1.0)
            The signal variance parameter.
    
    Returns:
        K: numpy array of shape (n1, n2)
            The kernel matrix between X1 and X2.
    """
    
    
    # Compute the pairwise squared Euclidean distances between the points
    dist = np.sum(X1**2, axis=1).reshape(-1, 1) + np.sum(X2**2, axis=1) - 2*np.dot(X1, X2.T)
    
    # Compute the kernel matrix using the squared exponential kernel function
    K = sigma_f**2 * np.exp(-0.5 * dist / l**2)
    
    return K

# %%
emt=np.empty((len(y),len(y)))
for i1 , y1 in enumerate(y):
    for i2,y2 in enumerate(y):
        emt[i1,i2]=1**2*np.exp(-.5*(y1-y2)/1)

# %%
emt
# Out:
# array([[1.        , 0.99330364, 0.95423213, 1.22654559, 1.4419416 ,
#         1.45499141],
#        [1.00674151, 1.        , 0.96066509, 1.23481435, 1.45166246,
#         1.46480025],
#        [1.04796304, 1.0409455 , 1.        , 1.28537444, 1.5111015 ,
#         1.52477722],
#        [0.81529787, 0.80983834, 0.77798342, 1.        , 1.17561191,
#         1.18625139],
#        [0.69350936, 0.68886537, 0.66176891, 0.85062085, 1.        ,
#         1.00905017],
#        [0.68728928, 0.68268694, 0.65583351, 0.84299163, 0.991031  ,
#         1.        ]])

# %%
stats.invgamma(1).rvs(10)[0]*np.identity(len(y)-1)
# Out:
# array([[1.66667612, 0.        , 0.        , 0.        , 0.        ],
#        [0.        , 1.66667612, 0.        , 0.        , 0.        ],
#        [0.        , 0.        , 1.66667612, 0.        , 0.        ],
#        [0.        , 0.        , 0.        , 1.66667612, 0.        ],
#        [0.        , 0.        , 0.        , 0.        , 1.66667612]])

# %%
sns.heatmap(squared_exponential_kernel2(y.reshape(-1,1),y.reshape(-1,1),0.5676536 , 0.07610351),annot=True)
# Out:
# <AxesSubplot:>

# %%
def multivariateNormal(x,k,l,L,sigma_f,a):
    x1=y
    x2=y
    mean=1/(1+np.exp((round(k)-x)/l))
    x1_sq = np.sum(x1**2) 
    x2_sq = np.sum(x2**2) 
    cov=squared_exponential_kernel2(y.reshape(-1,1),y.reshape(-1,1),L, sigma_f)+np.identity(len(y))*a
    results=stats.multivariate_normal.rvs(mean,cov=cov, size=1,random_state=6).T
    return results
popt, pcov = curve_fit(multivariateNormal, x, y,bounds=([0,0,-3,-3,0], [len(x),1,2,2,1]))
popt
# Out:
# array([3.        , 0.99773486, 0.44704076, 0.20832223, 0.00457859])

# %%
model=multivariateNormal(x,*popt)
plt.plot(x,y,c='navy',label='Observed Data')
plt.plot(x,yModel,'g--',label='Mean Function')
plt.plot(x,model,'r--',label='multivariateNormal Model')
plt.legend();
plt.xlabel('Number of questions')
plt.ylabel('Mastery level');
plt.grid();

# %%
n=100
emptyArray=np.zeros((n,len(x)))
for i in range(n):
    emptyArray[i]= model

# %%
resultdf=pd.DataFrame(pd.DataFrame(emptyArray).T.stack()).reset_index()

# %%
sns.lineplot(data=resultdf,x='level_0',y=0)
# Out:
# <AxesSubplot:xlabel='level_0', ylabel='0'>

# %%
df=pd.read_csv('goalprog.csv').set_index('user_id')

# %%
dataDict={}
for idx,row in df.iterrows():
    rowData=row.dropna().values
    dataDict[idx]= rowData

# %%
kList=[]
lList=[]
LList=[]
sigmaList=[]
aList=[]
userList=[]

for key,data in dataDict.items():
    print(key)
    y = data
    x=np.arange(1,len(y)+1)
    def multivariateNormal(x,k,l,L,sigma_f,a):
        x1=y
        x2=y
        mean=1/(1+np.exp((round(k)-x)/l))
        x1_sq = np.sum(x1**2) 
        x2_sq = np.sum(x2**2) 
        cov=squared_exponential_kernel2(y.reshape(-1,1),y.reshape(-1,1),L, sigma_f)+np.identity(len(y))*a
        results=stats.multivariate_normal.rvs(mean,cov=cov, size=1,random_state=6).T
        return results
    popt, pcov = curve_fit(multivariateNormal, x, y,bounds=([0,0,-3,-3,0], [len(x),1,2,2,1]))
    kList=popt[0]
    lList=popt[1]
    LList=popt[2]
    sigmaList=popt[3]
    aList=popt[4]
    userList.append(key)
# Out:
# 019f8b21-1059-4962-9cbc-70a978d14a79
# 023fc528-8b33-4431-8cb7-52f8fe00d422
# 02f57a11-9262-4fde-98e5-e28b0bfb2d3f
# 038d85a1-75f0-417b-b1a4-d443de4fb8d3
# 04237b29-88fb-4e99-9f09-d64c9690f065
# 04915991-36b3-4d3a-ab27-7e17ee13783d
# 075b550b-3364-498b-a34b-4aece5a6508b
# 07a5f0f4-66c3-431d-8e13-0ccb9da816b8
# 0a9b00d1-43d0-4022-a442-da8108298ac2
# 0cc5589e-6968-4d9e-8896-0ebee5bfb4d5
# 0edaf230-9925-4321-9a19-a032b87f927b
# 0ffe0d1d-89ff-433f-b115-e4a277a8fc29
# 12ad6e8d-7348-4054-8f5f-dec0e0cfa704
# 12c8b96a-9925-45f1-b2dc-78db0be15cc9
# 12f4e9ed-743e-4cf2-9e29-72fdf74e61d0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[49], line 21
#      19     results=stats.multivariate_normal.rvs(mean,cov=cov, size=1,random_state=6).T
#      20     return results
# ---> 21 popt, pcov = curve_fit(multivariateNormal, x, y,bounds=([0,0,-3,-3,0], [len(x),1,2,2,1]))
#      22 kList=popt[0]
#      23 lList=popt[1]
#
# File ~\Anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py:874, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, **kwargs)
#     870 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     871                     **kwargs)
#     873 if not res.success:
# --> 874     raise RuntimeError("Optimal parameters not found: " + res.message)
#     876 infodict = dict(nfev=res.nfev, fvec=res.fun)
#     877 ier = res.status
#
# RuntimeError: Optimal parameters not found: The maximum number of function evaluations is exceeded.

# %%
plt.plot(dataDict['12f4e9ed-743e-4cf2-9e29-72fdf74e61d0'])
