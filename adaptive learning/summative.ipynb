# %%
import pandas as pd
import  seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
pd.set_option('display.max_columns', None)

# %%
df=pd.read_pickle('appmath_summative.pkl')

# %%
df.groupby('test_name').correct.mean().hist()
# Out:
# <AxesSubplot:>

# %%
df.groupby('test_name').correct.mean().dropna()
# Out:
# test_name
# BUS 14 MidTerm                                                          0.784848
# Chapter 1 problem solving quiz                                          0.707237
# Chapter 11 Test                                                         0.697115
# Chapter 14 Test                                                         0.609722
# Chapter 2 Set Theory Quiz                                               0.710476
#                                                                           ...
# Unit 4 Quiz Irrational Numbers, Radicals, and the Real Number System    0.866667
# Unit 4 Quiz Order of Operations and Solving Equations                   0.900673
# Unit 5 Quiz The Metric System & Points, Lines, Angles, and Polygons     0.768879
# Unit 5 Quiz Transformations, Rotations, and Symmetry                    0.732919
# Unit 5 Quiz Triangles, Perimeter, Area, Volume and Surface Area         0.814815
# Name: correct, Length: 238, dtype: float64

# %%
df
# Out:
#                                     graph_id  \
# 133669  076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 133693  076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 133667  076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 133691  076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 133671  076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# ...                                      ...
# 46469   076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 46455   076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 46450   076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 46453   076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 46468   076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
#
#                                    course_id  \
# 133669  8f4601d5-9221-46e7-9b67-225e02a5acf3
# 133693  8f4601d5-9221-46e7-9b67-225e02a5acf3
# 133667  8f4601d5-9221-46e7-9b67-225e02a5acf3
# 133691  8f4601d5-9221-46e7-9b67-225e02a5acf3
# 133671  8f4601d5-9221-46e7-9b67-225e02a5acf3
# ...                                      ...
# 46469   adf7c57d-83b9-4653-834b-763ff1bcf722
# 46455   adf7c57d-83b9-4653-834b-763ff1bcf722
# ...
