# %%
import logging
import sys
import datetime
import pickle
from tqdm import tqdm
from sklearn.decomposition import PCA
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## for correct lstm shape - https://www.kaggle.com/code/imegirin/multivariate-time-series-modeling-with-pytorch

# %%
from torch.utils.data import TensorDataset

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt;
np.random.seed(30);
from sklearn.metrics import roc_auc_score;

# %%
from sklearn.metrics import roc_auc_score;
from sklearn.metrics import classification_report;

# %%
pd.set_option('display.max_columns', None);

# %%
df=pd.read_pickle('appmath.pkl')

# %%
df
# Out:
#                                      graph_id  \
# 2739785  076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 1971810  076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 1518532  076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 2063269  076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 2928085  076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# ...                                       ...
# 293507   076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 723858   076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 1068851  076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 300133   076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
# 300130   076e1a0e-669c-40c4-a23c-7ac2bbaa05cf
#
#                                     course_id  \
# 2739785  689c9d2c-b88e-40f1-9e5a-3a7193161cac
# 1971810  689c9d2c-b88e-40f1-9e5a-3a7193161cac
# 1518532  689c9d2c-b88e-40f1-9e5a-3a7193161cac
# 2063269  689c9d2c-b88e-40f1-9e5a-3a7193161cac
# 2928085  689c9d2c-b88e-40f1-9e5a-3a7193161cac
# ...                                       ...
# 293507   010d032f-1ba4-450a-98a7-1ef6d0ecffdf
# 723858   010d032f-1ba4-450a-98a7-1ef6d0ecffdf
# 1068851  010d032f-1ba4-450a-98a7-1ef6d0ecffdf
# 300133   010d032f-1ba4-450a-98a7-1ef6d0ecffdf
# 300130   010d032f-1ba4-450a-98a7-1ef6d0ecffdf
#
#                                    section_id  \
# 2739785  2dfdde50-72c3-4d49-8840-f0de82fedd0a
# 1971810  2dfdde50-72c3-4d49-8840-f0de82fedd0a
# 1518532  2dfdde50-72c3-4d49-8840-f0de82fedd0a
# 2063269  2dfdde50-72c3-4d49-8840-f0de82fedd0a
# 2928085  2dfdde50-72c3-4d49-8840-f0de82fedd0a
# ...                                       ...
# 293507   88011589-0c00-421e-bbb6-43decbae5a60
# 723858   88011589-0c00-421e-bbb6-43decbae5a60
# 1068851  88011589-0c00-421e-bbb6-43decbae5a60
# 300133   88011589-0c00-421e-bbb6-43decbae5a60
# 300130   88011589-0c00-421e-bbb6-43decbae5a60
#
#                                       user_id  \
# 2739785  0012ff2b-871a-45d6-8e33-804f7464fa0a
# 1971810  0012ff2b-871a-45d6-8e33-804f7464fa0a
# 1518532  0012ff2b-871a-45d6-8e33-804f7464fa0a
# 2063269  0012ff2b-871a-45d6-8e33-804f7464fa0a
# 2928085  0012ff2b-871a-45d6-8e33-804f7464fa0a
# ...                                       ...
# 293507   fff245f4-b76c-4ed3-ae05-84a25bfd92ad
# 723858   fff245f4-b76c-4ed3-ae05-84a25bfd92ad
# 1068851  fff245f4-b76c-4ed3-ae05-84a25bfd92ad
# 300133   fff245f4-b76c-4ed3-ae05-84a25bfd92ad
# 300130   fff245f4-b76c-4ed3-ae05-84a25bfd92ad
#
#                               registration_id  \
# 2739785  0bbde3de-283b-4b08-a783-1a2942d07a2e
# 1971810  0bbde3de-283b-4b08-a783-1a2942d07a2e
# 1518532  0bbde3de-283b-4b08-a783-1a2942d07a2e
# 2063269  630b3513-7534-4ebc-8fe6-4625ad5ae796
# 2928085  630b3513-7534-4ebc-8fe6-4625ad5ae796
# ...                                       ...
# 293507   8083395f-08de-4c5f-b585-e66d50a8f55c
# 723858   8083395f-08de-4c5f-b585-e66d50a8f55c
# 1068851  8083395f-08de-4c5f-b585-e66d50a8f55c
# 300133   8083395f-08de-4c5f-b585-e66d50a8f55c
# 300130   8083395f-08de-4c5f-b585-e66d50a8f55c
#
#                                       goal_id  \
# 2739785  e359efc4-ed49-4227-a03e-c0c9358487d3
# 1971810  e359efc4-ed49-4227-a03e-c0c9358487d3
# 1518532  e359efc4-ed49-4227-a03e-c0c9358487d3
# 2063269  4debeb6d-fc33-46ad-a19b-307c7ae270d0
# 2928085  4debeb6d-fc33-46ad-a19b-307c7ae270d0
# ...                                       ...
# 293507   209abe07-67d8-4e6e-857a-7853810efcf5
# 723858   209abe07-67d8-4e6e-857a-7853810efcf5
# 1068851  209abe07-67d8-4e6e-857a-7853810efcf5
# 300133   209abe07-67d8-4e6e-857a-7853810efcf5
# 300130   209abe07-67d8-4e6e-857a-7853810efcf5
#
#                                       path_id path_type adaptive_behavior  \
# 2739785  009f012a-30c9-42c5-94c6-3e05008ccfd0    REVIEW              None
# 1971810  009f012a-30c9-42c5-94c6-3e05008ccfd0    REVIEW              None
# 1518532  009f012a-30c9-42c5-94c6-3e05008ccfd0    REVIEW              None
# 2063269  0e2c0048-8974-4e02-93ce-443075bb7087  ADAPTIVE          PRACTICE
# 2928085  0e2c0048-8974-4e02-93ce-443075bb7087  ADAPTIVE          PRACTICE
# ...                                       ...       ...               ...
# 293507   c0845a6f-077a-49bb-9f4e-4e0ccd5cc8c8  ADAPTIVE          PRACTICE
# 723858   c0845a6f-077a-49bb-9f4e-4e0ccd5cc8c8  ADAPTIVE          PRACTICE
# 1068851  c0845a6f-077a-49bb-9f4e-4e0ccd5cc8c8  ADAPTIVE          PRACTICE
# 300133   c0845a6f-077a-49bb-9f4e-4e0ccd5cc8c8  ADAPTIVE          PRACTICE
# 300130   c0845a6f-077a-49bb-9f4e-4e0ccd5cc8c8  ADAPTIVE          PRACTICE
#
#                                      topic_id  lo_to_concept_blacklist  \
# 2739785  d5743794-1f74-46ca-a538-8bf6c1cbb30b                      NaN
# 1971810  d5743794-1f74-46ca-a538-8bf6c1cbb30b                      NaN
# 1518532  d5743794-1f74-46ca-a538-8bf6c1cbb30b                      NaN
# 2063269  00b67632-3af0-47f7-ac19-77c8c686244b                      NaN
# 2928085  00b67632-3af0-47f7-ac19-77c8c686244b                      NaN
# ...                                       ...                      ...
# 293507   b76976e3-85ef-470d-8946-290aa148133e                      NaN
# 723858   b76976e3-85ef-470d-8946-290aa148133e                      NaN
# 1068851  b76976e3-85ef-470d-8946-290aa148133e                      NaN
# 300133   b76976e3-85ef-470d-8946-290aa148133e                      NaN
# 300130   b76976e3-85ef-470d-8946-290aa148133e                      NaN
#
#            interaction_end_time                            concept_id  \
# 2739785 2022-10-02 16:17:07.342  b7d9982e-26f9-47c0-b76f-cc9dc1f0bfbe
# 1971810 2022-10-02 16:17:42.073  b7d9982e-26f9-47c0-b76f-cc9dc1f0bfbe
# 1518532 2022-10-02 16:17:42.341  b7d9982e-26f9-47c0-b76f-cc9dc1f0bfbe
# 2063269 2022-12-16 18:34:22.470  d02dcdf8-70dd-46db-bd8b-0894f303871d
# 2928085 2022-12-16 18:35:06.209  d02dcdf8-70dd-46db-bd8b-0894f303871d
# ...                         ...                                   ...
# 293507  2022-09-03 03:45:59.691  0f9863ff-d7a9-4db8-8361-a2419f50ec8a
# 723858  2022-09-03 04:16:48.569  0f9863ff-d7a9-4db8-8361-a2419f50ec8a
# 1068851 2022-09-03 04:27:39.891  0f9863ff-d7a9-4db8-8361-a2419f50ec8a
# 300133  2022-09-03 04:31:52.200  0f9863ff-d7a9-4db8-8361-a2419f50ec8a
# 300130  2022-09-03 04:33:19.491  0f9863ff-d7a9-4db8-8361-a2419f50ec8a
#
#                            concept_partner_id  \
# 2739785  53568360-e9fe-465f-a8fc-1c75027cba94
# 1971810  53568360-e9fe-465f-a8fc-1c75027cba94
# 1518532  53568360-e9fe-465f-a8fc-1c75027cba94
# 2063269  e5dfa5f5-7ded-4b39-911e-b2b1737007a1
# 2928085  e5dfa5f5-7ded-4b39-911e-b2b1737007a1
# ...                                       ...
# 293507   b6d144af-1fa6-4ca0-af24-a860418b0c61
# 723858   b6d144af-1fa6-4ca0-af24-a860418b0c61
# 1068851  b6d144af-1fa6-4ca0-af24-a860418b0c61
# 300133   b6d144af-1fa6-4ca0-af24-a860418b0c61
# 300130   b6d144af-1fa6-4ca0-af24-a860418b0c61
#
#                                               concept_name  \
# 2739785  Construct a truth table for a conditional stat...
# 1971810  Construct a truth table for a conditional stat...
# 1518532  Construct a truth table for a conditional stat...
# 2063269        Determine the sample space of an experiment
# 2928085        Determine the sample space of an experiment
# ...                                                    ...
# 293507   Solve inequalities that involve rational expre...
# 723858   Solve inequalities that involve rational expre...
# 1068851  Solve inequalities that involve rational expre...
# 300133   Solve inequalities that involve rational expre...
# 300130   Solve inequalities that involve rational expre...
#
#                                  retail_lo_id  \
# 2739785  53568360-e9fe-465f-a8fc-1c75027cba94
# 1971810  53568360-e9fe-465f-a8fc-1c75027cba94
# 1518532  53568360-e9fe-465f-a8fc-1c75027cba94
# 2063269  e5dfa5f5-7ded-4b39-911e-b2b1737007a1
# 2928085  e5dfa5f5-7ded-4b39-911e-b2b1737007a1
# ...                                       ...
# 293507   b6d144af-1fa6-4ca0-af24-a860418b0c61
# 723858   b6d144af-1fa6-4ca0-af24-a860418b0c61
# 1068851  b6d144af-1fa6-4ca0-af24-a860418b0c61
# 300133   b6d144af-1fa6-4ca0-af24-a860418b0c61
# 300130   b6d144af-1fa6-4ca0-af24-a860418b0c61
#
#                                    learning_objective_name  \
# 2739785  Construct a truth table for a conditional stat...
# 1971810  Construct a truth table for a conditional stat...
# 1518532  Construct a truth table for a conditional stat...
# 2063269        Determine the sample space of an experiment
# 2928085        Determine the sample space of an experiment
# ...                                                    ...
# 293507   Solve inequalities that involve rational expre...
# 723858   Solve inequalities that involve rational expre...
# 1068851  Solve inequalities that involve rational expre...
# 300133   Solve inequalities that involve rational expre...
# 300130   Solve inequalities that involve rational expre...
#
#                                       atom_id  \
# 2739785  90bf68ef-fa40-4c57-9054-c417a848d897
# 1971810  49287c70-b63d-41be-9acc-24fd1f273158
# 1518532  b2b1e778-26e0-4c99-ad3f-8ac5e8838a49
# 2063269  1beef294-92f4-40f5-a340-b02f4cc9970c
# 2928085  f6486631-0b5e-4e95-a149-24418015abc2
# ...                                       ...
# 293507   79d7f1d0-5bae-4494-849d-9643cd6f5482
# 723858   a75b7742-0355-4e60-9164-06a07233b05c
# 1068851  50ba61e6-a3e9-4966-8c3b-fec0da397e64
# 300133   1f1722b2-0ccc-413c-96a7-ceee5b026332
# 300130   0f85d947-0b16-4a3a-a5ae-e24102ad401d
#
#                                retail_atom_id  \
# 2739785  5e457b03-88e7-4798-9c17-0c44a1c2d419
# 1971810  614cad88-03e6-4c22-9689-aab68b3f23ba
# 1518532  fa2a4b85-28c2-460d-b6ee-3e4686ad7db8
# 2063269  a72b2188-29fd-4a11-9970-a0583361ccbf
# 2928085  e3d0e917-c76b-4839-8769-8c9ca2a90456
# ...                                       ...
# 293507   64198559-cead-4218-962d-537e07f2d031
# 723858   4f772302-c43f-4c7d-8f88-23503134a508
# 1068851  8292c0f1-89fc-4a3e-9b78-35a03590eace
# 300133   fefc3e36-ae46-44bf-a620-5b26e048d8fc
# 300130   4c3da3f6-5ef4-4818-990d-8e6724353ee6
#
#                                  variation_id     sequence_created_at  \
# 2739785  4ffcf121-73c3-4e21-adb9-d117faecffe9 2022-10-02 15:57:10.382
# 1971810  5dd2e89c-bbcf-41ca-a91c-052010465d40 2022-10-02 16:17:07.893
# 1518532  246cb150-9245-4042-b9b3-9392bab4ccfc 2022-10-02 16:17:42.341
# 2063269  6991ec82-96a0-4f31-9dd7-a2b8ab59c60f 2022-11-07 01:26:59.387
# 2928085  ca492a10-eeef-407d-8438-65b8931abe16 2022-12-16 18:34:22.691
# ...                                       ...                     ...
# 293507   7d4d1c0b-71a3-49e4-9f57-22a288f75e76 2022-09-03 03:20:16.071
# 723858   2decf2e9-919a-44a6-9839-cca0d17eb966 2022-09-03 03:20:16.071
# 1068851  b64c4835-cbf1-4ad8-b233-cf37bba079a9 2022-09-03 03:20:16.071
# 300133   dc4f365f-857c-4faa-b64b-b308ea58f861 2022-09-03 04:27:40.141
# 300130   e2f9a60b-253b-462d-89ca-76dbc8500997 2022-09-03 04:31:52.410
#
#                            parent_sequence_id  \
# 2739785  5baf1afa-5bc6-4c72-a7ac-b1bd4f180d22
# 1971810  a9af40ef-a988-4a30-b1fc-2344676d4cc7
# 1518532  340e10ca-1ab2-4559-8e89-4cd3eac53277
# 2063269  85e666eb-f520-4557-8fec-dfce666e74d3
# 2928085  dde93db0-3f94-4040-aee4-2a9d4545b2f2
# ...                                       ...
# 293507   0533c3df-688a-42b8-8c05-40719fbfab74
# 723858   0533c3df-688a-42b8-8c05-40719fbfab74
# 1068851  0533c3df-688a-42b8-8c05-40719fbfab74
# 300133   da983f20-0443-432c-b530-0918b71a36ac
# 300130   86346ff3-343c-45dd-86f9-8c20594fce72
#
#                          sequence_instance_id  sequence_ordinal  \
# 2739785  c3b5bff2-e288-473d-bc1b-88c38be34d35                 1
# 1971810  408fc057-0815-4940-8ede-1ebe8207c1f0                 1
# 1518532  a3dbdfe0-2d1f-4b6b-927c-366acdbc0763                 1
# 2063269  c705f1e8-76da-4a5d-83fb-a8016058f580                 1
# 2928085  41a40839-caa9-4fa6-9570-a0ff4aa97eb1                 1
# ...                                       ...               ...
# 293507   1c4a473f-6a2d-4ba3-bc72-2227058b197f                 2
# 723858   1c4a473f-6a2d-4ba3-bc72-2227058b197f                 3
# 1068851  1c4a473f-6a2d-4ba3-bc72-2227058b197f                 4
# 300133   956525c4-c10a-466e-8c0d-4e8a00b7e3d8                 1
# 300130   d02240a5-1554-4ce1-ad30-342a5fc9a5d7                 1
#
#          recommendation_id            source  state    type correct  \
# 2739785       6.982368e+18    RECOMMENDATION   DONE  ASSESS   False
# 1971810       6.982373e+18    RECOMMENDATION   DONE  ASSESS    True
# 1518532       6.982373e+18    RECOMMENDATION  SHOWN  ASSESS    None
# 2063269       6.995195e+18    RECOMMENDATION   DONE  ASSESS   False
# 2928085       6.995195e+18    RECOMMENDATION   DONE  ASSESS    True
# ...                    ...               ...    ...     ...     ...
# 293507                 NaN  MORE_INSTRUCTION   DONE  ASSESS    True
# 723858                 NaN  MORE_INSTRUCTION   DONE   TEACH    None
# 1068851                NaN  MORE_INSTRUCTION   DONE  ASSESS    True
# 300133        6.971685e+18    RECOMMENDATION   DONE  ASSESS    True
# 300130        6.971686e+18    RECOMMENDATION   DONE  ASSESS    True
#
#          time_spent_answering_s  time_spent_on_instruction_s  goal_progress  \
# 2739785              396.441010                    24.492001       0.037663
# 1971810               26.042000                     8.122000       0.533186
# 1518532                0.000000                     0.000000            NaN
# 2063269               87.829002                     3.608000       0.007354
# 2928085               42.161999                     1.341000       0.048507
# ...                         ...                          ...            ...
# 293507              1522.884033                    20.736000       0.250000
# 723858                 0.000000                     0.000000            NaN
# 1068851                0.000000                     4.422000       0.500000
# 300133               235.667999                    16.375999       0.750000
# 300130                77.462997                     9.606000       1.000000
#
#          work_remaining       status  \
# 2739785            -1.0  in_progress
# 1971810            -1.0  in_progress
# 1518532             NaN          NaN
# 2063269            -1.0  in_progress
# 2928085            -1.0  in_progress
# ...                 ...          ...
# 293507             -1.0  in_progress
# 723858              NaN          NaN
# 1068851            -1.0  in_progress
# 300133              1.0  in_progress
# 300130              0.0     complete
#
#                                 target_status_and_progress  \
# 2739785  {'53568360-e9fe-465f-a8fc-1c75027cba94': {'pro...
# 1971810  {'53568360-e9fe-465f-a8fc-1c75027cba94': {'pro...
# 1518532                                                NaN
# 2063269  {'e5dfa5f5-7ded-4b39-911e-b2b1737007a1': {'pro...
# 2928085  {'e5dfa5f5-7ded-4b39-911e-b2b1737007a1': {'pro...
# ...                                                    ...
# 293507   {'b6d144af-1fa6-4ca0-af24-a860418b0c61': {'pro...
# 723858                                                 NaN
# 1068851  {'b6d144af-1fa6-4ca0-af24-a860418b0c61': {'pro...
# 300133   {'b6d144af-1fa6-4ca0-af24-a860418b0c61': {'pro...
# 300130   {'b6d144af-1fa6-4ca0-af24-a860418b0c61': {'pro...
#
#         prev_concept_narrative current_concept_narrative  \
# 2739785    DIRECT_CHOOSE_TOPIC     DIRECT_DIAGNOSE_TOPIC
# 1971810  DIRECT_DIAGNOSE_TOPIC     DIRECT_DIAGNOSE_TOPIC
# 1518532          REVIEW_SWITCH           REVIEW_PRE_TEST
# 2063269    DIRECT_CHOOSE_TOPIC     DIRECT_DIAGNOSE_TOPIC
# 2928085  DIRECT_DIAGNOSE_TOPIC     DIRECT_DIAGNOSE_TOPIC
# ...                        ...                       ...
# 293507                     NaN                       NaN
# 723858                     NaN                       NaN
# 1068851                    NaN                       NaN
# 300133   DIRECT_DIAGNOSE_TOPIC       DIRECT_ASSESS_TOPIC
# 300130     DIRECT_ASSESS_TOPIC       DIRECT_ASSESS_TOPIC
#
#                            focused_concept_id prev_lo_narrative  \
# 2739785  b7d9982e-26f9-47c0-b76f-cc9dc1f0bfbe              NONE
# 1971810  b7d9982e-26f9-47c0-b76f-cc9dc1f0bfbe              NONE
# 1518532  b7d9982e-26f9-47c0-b76f-cc9dc1f0bfbe              NONE
# 2063269  d02dcdf8-70dd-46db-bd8b-0894f303871d              NONE
# 2928085  d02dcdf8-70dd-46db-bd8b-0894f303871d              NONE
# ...                                       ...               ...
# 293507                                    NaN               NaN
# 723858                                    NaN               NaN
# 1068851                                   NaN               NaN
# 300133   0f9863ff-d7a9-4db8-8361-a2419f50ec8a              NONE
# 300130   0f9863ff-d7a9-4db8-8361-a2419f50ec8a              NONE
#
#         current_lo_narrative                         focused_lo_id  \
# 2739785                 NONE  ff1bfcee-603f-4b08-924a-3852972fffab
# 1971810                 NONE  ff1bfcee-603f-4b08-924a-3852972fffab
# 1518532                 NONE  ff1bfcee-603f-4b08-924a-3852972fffab
# 2063269                 NONE  c85a591f-8169-4ea8-af31-f89a007f6a7e
# 2928085                 NONE  c85a591f-8169-4ea8-af31-f89a007f6a7e
# ...                      ...                                   ...
# 293507                   NaN                                   NaN
# 723858                   NaN                                   NaN
# 1068851                  NaN                                   NaN
# 300133                  NONE  91e5de2c-6a41-48c0-aa7d-18876a233e38
# 300130                  NONE  91e5de2c-6a41-48c0-aa7d-18876a233e38
#
#                                   focused_topic_id   duration_s  is_target
# 2739785  tref-d5743794-1f74-46ca-a538-8bf6c1cbb30b   420.933014       True
# 1971810  tref-d5743794-1f74-46ca-a538-8bf6c1cbb30b    34.164001       True
# 1518532  tref-d5743794-1f74-46ca-a538-8bf6c1cbb30b     0.000000       True
# 2063269  tref-00b67632-3af0-47f7-ac19-77c8c686244b    91.437004       True
# 2928085  tref-00b67632-3af0-47f7-ac19-77c8c686244b    43.502998       True
# ...                                            ...          ...        ...
# 293507                                         NaN  1543.619995       True
# 723858                                         NaN     0.000000       True
# 1068851                                        NaN     4.422000       True
# 300133   tref-b76976e3-85ef-470d-8946-290aa148133e   252.044006       True
# 300130   tref-b76976e3-85ef-470d-8946-290aa148133e    87.069000       True
#
# [3072104 rows x 44 columns]

# %%
df=pd.read_pickle('appmath.pkl')[['graph_id', 'user_id', 
       'goal_id',
        'interaction_end_time',
       'learning_objective_name', 'atom_id', 
       'correct', 'time_spent_answering_s', 'time_spent_on_instruction_s',
       'goal_progress',
       'target_status_and_progress', 'prev_concept_narrative',
       'duration_s', 'is_target']]

# %%
df2=pd.read_csv('prereq_edges.csv')

# %%
G=nx.Graph()

for _,i in df2.iterrows():    
       
        G.add_edge(i['source_lo_title'],i['dest_lo_title'])
        
subgraphs=[G.subgraph(i) for i in nx.connected_components(G)]

for num,sub in enumerate(subgraphs):
    
    nx.set_node_attributes(sub,num,'subGraphId')

nodeSubGraphId={}
for g in subgraphs:
    for node in g.nodes(data=True):
         nodeSubGraphId[node[0]]= node[1]['subGraphId']
            
subgraphsNodeCountDict={ num: g.number_of_nodes() for num,g in  enumerate(subgraphs)}

# %%
for col in df.columns:
    if df[col].dtype.name=='category':
        df[col]=df[col].astype(str)

# %%
df['loGraphID']=df.learning_objective_name.apply(lambda x: nodeSubGraphId.get(x) )

# %%
difficulty=df[~df.correct.isna()].groupby('atom_id')['correct'].mean().reset_index().rename(columns={'correct':'difficulty'})
df=df.merge(difficulty,how='left',on='atom_id')

# %%
lo_difficulty=df[~df.correct.isna()].groupby('learning_objective_name')['correct'].mean().reset_index().rename(columns={'correct':'lo_difficulty'})
df=df.merge(lo_difficulty,how='left',on='learning_objective_name')

# %%
df['correctBinary']=df.correct*1
df.atom_id=df.atom_id.astype(str)

# %%
df=df[~df.correctBinary.isna()]

# %%
df2['graph_id']=df2.apply(lambda x: nodeSubGraphId.get(x['source_lo_title']) if nodeSubGraphId.get(x['source_lo_title'])!=None else nodeSubGraphId.get(x['dest_lo_title']),axis=1)

# %%
unique_lo_graph_id_dic={}
for i in df2.graph_id.unique():
    unique_lo=np.unique(np.concatenate((df2[df2.graph_id==i]['source_lo_title'].unique(),((df2[df2.graph_id==i]['dest_lo_title'].unique())))))
    unique_lo_graph_id_dic[i]={ item:int(num)  for  num,item in enumerate(unique_lo)}
    df2.loc[df2.graph_id==i,'source_index' ]=df2.apply(lambda x: unique_lo_graph_id_dic.get(i).get(x['source_lo_title']),axis=1)
    df2.loc[df2.graph_id==i,'dest_index' ]=df2.apply(lambda x: unique_lo_graph_id_dic.get(i).get(x['dest_lo_title']),axis=1)

# %%
df2.source_index=df2.source_index.astype(int)
df2.dest_index=df2.dest_index.astype(int)

# %%
df=df[~df.loGraphID.isna()]

# %%
df2[df2.graph_id==3].max()
# Out:
# source_lo_id                    eda7ab6a-8070-4fd8-8387-da17a40fd99e
# dest_lo_id                      eda7ab6a-8070-4fd8-8387-da17a40fd99e
# source_lo_title    Write biconditional statements in symbolic for...
# dest_lo_title      Write biconditional statements in symbolic for...
# graph_id                                                           3
# source_index                                                      30
# dest_index                                                        30
# dtype: object

# %%
summary=df.pivot_table(index='goal_id',aggfunc={'learning_objective_name':pd.Series.nunique,'atom_id':pd.Series.nunique,'user_id':pd.Series.nunique,'interaction_end_time':np.count_nonzero})

# %%
summary['atom_usage']=summary.interaction_end_time/summary.atom_id

# %%
summary.sort_values('atom_usage',ascending=False).head(10)
# Out:
#                                       atom_id  interaction_end_time  \
# goal_id
# 39f38cfd-d153-4fcf-950e-5c1b2bfbeaaa       72                  8793
# d252b7df-6a57-46ff-b4c3-e21d26d80b6a       82                  9887
# cd26c1cb-87ad-4b57-bdeb-7e8811827e39       59                  5764
# 86940cba-2a55-43a6-8f51-248afca9952d       26                  1974
# caacf0e3-8698-4806-8ce8-a45d8f75b587       59                  4396
# 12b7f97f-18be-4a9e-9384-866a036631d4      103                  7107
# 9059c88d-ccdd-42dd-a19f-fe7c9bafd6aa       47                  3236
# 46e93a47-9de8-4982-82ec-6e3acb911c54      116                  7116
# 917d2bb2-451f-4f65-8eec-7a8125c9a596       39                  2220
# ebb614bf-c45c-4b77-a5f7-168e4569b280       32                  1782
#
#                                       learning_objective_name  user_id  \
# goal_id
# 39f38cfd-d153-4fcf-950e-5c1b2bfbeaaa                        3      289
# d252b7df-6a57-46ff-b4c3-e21d26d80b6a                        5      253
# cd26c1cb-87ad-4b57-bdeb-7e8811827e39                        3      194
# 86940cba-2a55-43a6-8f51-248afca9952d                        1      291
# caacf0e3-8698-4806-8ce8-a45d8f75b587                        3      240
# 12b7f97f-18be-4a9e-9384-866a036631d4                        5      260
# 9059c88d-ccdd-42dd-a19f-fe7c9bafd6aa                        2      255
# 46e93a47-9de8-4982-82ec-6e3acb911c54                        6      240
# 917d2bb2-451f-4f65-8eec-7a8125c9a596                        2      140
# ebb614bf-c45c-4b77-a5f7-168e4569b280                        2      119
#
#                                       atom_usage
# goal_id
# 39f38cfd-d153-4fcf-950e-5c1b2bfbeaaa  122.125000
# d252b7df-6a57-46ff-b4c3-e21d26d80b6a  120.573171
# cd26c1cb-87ad-4b57-bdeb-7e8811827e39   97.694915
# 86940cba-2a55-43a6-8f51-248afca9952d   75.923077
# caacf0e3-8698-4806-8ce8-a45d8f75b587   74.508475
# 12b7f97f-18be-4a9e-9384-866a036631d4   69.000000
# 9059c88d-ccdd-42dd-a19f-fe7c9bafd6aa   68.851064
# 46e93a47-9de8-4982-82ec-6e3acb911c54   61.344828
# 917d2bb2-451f-4f65-8eec-7a8125c9a596   56.923077
# ebb614bf-c45c-4b77-a5f7-168e4569b280   55.687500

# %%
(1-lo_difficulty.lo_difficulty).hist()
# Out:
# <AxesSubplot:>

# %%
import torch_geometric as pyg
from torch_geometric.nn import GCNConv ,ResGatedGraphConv
from torch_geometric.nn import SAGEConv, to_hetero ,LSTMAggregation
import  torch.nn as nn
import torch.nn.functional as F
import torch 
from torch_geometric.loader import DataLoader
import torch_geometric.transforms as T
from torch_geometric.data import HeteroData
import torch 
torch.manual_seed(0)

# %% [markdown]
# # train_test_split

# %%
def train_test_split(df,df2,look_back=3,loGraphID=3,user_count=4):
    df=df[~df.correctBinary.isna()]
    users=df[df.loGraphID==loGraphID].user_id.sample(user_count).values
    dfg=df[(df.loGraphID==loGraphID) & (df.user_id.isin(users)) ].reset_index(drop=True)
    
    dfg=dfg.sort_values(['user_id','interaction_end_time'])
    
    atom_index={atom_id:i for i,atom_id  in  enumerate(dfg.atom_id.unique())}

    dfg['atomIndex']=dfg.atom_id.map(atom_index)
    #atom_edges,cosin_sim_vals=atom_similarity(dfg)
    loEdgeMapping=df2[df2['graph_id']==loGraphID][['source_index','dest_index']]
    lo_edges=loEdgeMapping.values.transpose()
    
    lo_map=pd.concat([df2[df2['graph_id']==loGraphID][['source_lo_title','source_index']].rename(columns={'source_lo_title':'learning_objective_name','source_index':'loIndex'}),
                      df2[df2['graph_id']==loGraphID][['dest_lo_title','dest_index']].rename(columns={'dest_lo_title':'learning_objective_name','dest_index':'loIndex'})]).drop_duplicates().reset_index(drop=True)
    
    dfg['atomIndex']=dfg.atom_id.map(atom_index)
    
    dfg=dfg.merge(lo_map,on='learning_objective_name',how='left')
    
    
    users_question_sequence=[]
    for user in users:
        print(user)
        question_sequence=dfg[dfg.user_id==user][['loIndex','atomIndex','correctBinary']].values.transpose()
        question_sequence_len=question_sequence.shape[1]
        train_size=int(question_sequence_len*.8)
        users_question_sequence.append(question_sequence)
    
    lo_atom_edges_list=dfg.groupby(['loIndex','atomIndex']).count().index.to_list()
    
    #question_sequence_len=question_sequence.shape[1]
    
    l1,l2=zip(*lo_atom_edges_list)
    
    lo_atom_edges=np.array((list(l1),list(l2)))
 
    atomFeatures=dfg.groupby('atomIndex')['difficulty'].mean().values.reshape(-1,1)
    #loFeatures=np.zeros(31 ).reshape(-1,1)
    loFeatures=df[df.loGraphID==3].groupby('lo_difficulty')['difficulty'].mean().values.reshape(-1,1)
    
    data = HeteroData()

    data['atom'].x=torch.tensor(atomFeatures.astype(np.float64)).float()
   
    data['lo'].x= torch.tensor(loFeatures.astype(np.float64)).float()
    
    
    data['lo','lo_atom','atom'].edge_index=torch.from_numpy(lo_atom_edges).long()
    data['lo','lo_lo','lo'].edge_index=torch.from_numpy(lo_edges).long()
    
    
    
    normalize=T.NormalizeFeatures()
    graph=normalize(data)
       
    return graph,users_question_sequence,dfg

# %%
lookback=3
find_user=True


data,users_question_sequence,dfg=train_test_split(df,df2,user_count=3,look_back=lookback)
total_len=(sum([len(i[1]) for i in users_question_sequence]))
total_len
# Out:
# 326768a4-3821-4148-b0c9-c41eaa32752a
# a4b7ffa7-f413-48e0-84b9-44847302a4f9
# e8ff259b-5858-44e8-a8d6-900ce7afcbb3
# 1391

# %%
data
# Out:
# HeteroData(
#   atom={ x=[550, 1] },
#   lo={ x=[31, 1] },
#   (lo, lo_atom, atom)={ edge_index=[2, 550] },
#   (lo, lo_lo, lo)={ edge_index=[2, 41] }
# )

# %%
#dfg.groupby( atomIndex)['atomIndex'].agg(list)

# %% [markdown]
# ### balanced users
# b2183f14-2da0-4ee5-ab2e-fa27c223e03a
#
#
#
#
# a2eb5835-17d2-4f78-8621-b6643289eae9
#
#
# a5fbbfd0-b7eb-45c9-9948-265c813b9ed1
#
#
# 85629129-9333-4ee5-866f-6a9be8769c82

# %%
from torch_geometric.nn import global_mean_pool as gap, global_max_pool as gmp

# %%
def test(model):
    with torch.no_grad():
        total_loss=0
        model_accuracy=[]
        for user_num,question_sequence in enumerate(users_question_sequence):
                question_sequence_len=int(question_sequence.shape[1]*.80)
               
                batch_accuracy=[]
                batch_target=[]
                batch_prob=[]

                for  batch_num in range(question_sequence_len,question_sequence.shape[1]):

                    model.eval()

                    answer=torch.tensor([question_sequence[2][batch_num]]).float()

                    out,node_embeddings=model(data.x_dict, data.edge_index_dict,batch_num,lookback,question_sequence) 
                    loss=F.binary_cross_entropy(out,answer)
               
                    train_correct=out.round()==answer

                    train_acc=train_correct*1
                    accuracy=(train_correct*1).item()
                    epoch_accuracy.append(accuracy)
                    prob.append(out.item())
                    target.append(answer.item())
                    batch_target.append(answer.item())
                    batch_prob.append(out.item() )
                    batch_accuracy.append(accuracy)
                    total_loss=total_loss+loss.item()
                batch_performance = 'test_sequence_size : {} | loss {} | accuracy {:.5f} | auc {:.5f} \n'.format(question_sequence.shape[1]-question_sequence_len,
                                                                                                       total_loss/(question_sequence.shape[1]-question_sequence_len),
                                                                                                        np.mean(batch_accuracy),
                                                                                                       roc_auc_score(np.array(batch_target), batch_prob))

                print(batch_performance)
                model_accuracy.extend(batch_accuracy)
        print(f"model accuracy {np.mean(model_accuracy)} \n")
        return total_loss/(question_sequence.shape[1]-question_sequence_len)

# %%
hidden_channels=100
final_layer_dim=int(hidden_channels/4)
class GNN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = SAGEConv((-1, -1), hidden_channels,requires_grad=True)
        self.actfn1=nn.ReLU()
        
        self.conv2 = SAGEConv((-1, -1),int( hidden_channels/2),requires_grad=True)
        self.actfn2=nn.ReLU()
        
        self.conv3 = SAGEConv((-1, -1),int( hidden_channels/2),requires_grad=True)
        self.actfn3=nn.ReLU()
        
        self.conv4 = SAGEConv((-1, -1),int( final_layer_dim),requires_grad=True)
        self.actfn4=nn.ReLU()
        
        self.sigmoid= nn.Sigmoid()

    def forward(self, x, edge_index):
        
        x = self.actfn1(self.conv1(x, edge_index))
        #x= F.dropout(x,p=.5,training=self.training)
        
        x = self.actfn2(self.conv2(x, edge_index))
        #x= F.dropout(x,p=.7,training=self.training)
        
        #x = self.actfn3(self.conv3(x, edge_index))
        
        x = self.actfn4(self.conv3(x, edge_index))
        #out = self.actfn4(self.conv4(x, edge_index))
        

        return x

# %%
hidden_channels1=final_layer_dim*4+lookback

out_channels=1
class Classifer(torch.nn.Module):
    def __init__(self):
        super(Classifer,self).__init__()

        self.ins = nn.Linear(hidden_channels1, 10)
        self.actfn1 = nn.ReLU()

        self.ins2 = nn.Linear(10, 5)
        self.actfn2 = nn.ReLU()

        self.out = nn.Linear(5, 1)
        self.actfn3 = nn.Sigmoid()


    def forward(self, x):
        x = self.actfn1(self.ins(x))

        x = self.actfn2(self.ins2(x))

        out = self.actfn3(self.out(x))

        return out

# %%
class GNN_Classifier(nn.Module):
    def __init__(self):
        super(GNN_Classifier, self).__init__()
        self.model_embedding = GNN()
        self.model_embedding = to_hetero(self.model_embedding, data.metadata(),aggr='max')
        self.classifer = Classifer()
        self.answers_weight=torch.ones(lookback,requires_grad=True)
        
        
    def forward(self, x,edges,batch_num,lookback,question_sequence):
        #print(self.answers_weight)
        node_embeddings = self.model_embedding(x,edges)
        features_concat_list=[]
        
        current_lo=question_sequence[0][batch_num]
        current_atom=question_sequence[1][batch_num]
        features_concat_list.extend([node_embeddings['atom'][current_atom]])
        features_concat_list.extend([node_embeddings['lo'][current_lo]])
        
      
        
        attempted = question_sequence[0][:batch_num]
        
        attempted_lo=attempted==current_lo
        
        attempted_anwswers =question_sequence[2][:batch_num][attempted_lo].astype(float)
        
        answers_place_holder= torch.tensor([-1 for i in range(lookback)])
        #print(f'answers_place_holder {answers_place_holder}')
        #print(f'attempted_anwswers[-lookback:] {attempted_anwswers[-lookback:]}')
        #if len(attempted_anwswers)>0:
            #answers_place_holder[:lookback]=torch.tensor(attempted_anwswers[-lookback:])
        
        #print(f'answers_place_holder {answers_place_holder}')

        if attempted_anwswers.shape[0]>=lookback:
          
            answers_place_holder=torch.tensor(attempted_anwswers[-lookback:])
            
            
        elif attempted_anwswers.shape[0]<lookback and attempted_anwswers.shape[0]>0:
            
            answers_place_holder[-len(attempted_anwswers):]=torch.tensor(attempted_anwswers)
            

        
        
        
        #lookback_answers=lookback_answers.view(1,1)
        
        features_concat_list.extend([answers_place_holder])                        
        #print(features_concat_list)
        user_embeddings=torch.cat(features_concat_list)
        user_embeddings=user_embeddings.float()
       
        rnn_outputs = self.classifer(user_embeddings)
    
        return rnn_outputs,user_embeddings

# %%
model=GNN_Classifier()
learning_rate=0.01
optimizer=torch.optim.Adam(model.parameters(),lr=learning_rate,weight_decay=5e-12)
criterion=torch.nn.BCELoss()
#criterion=F.binary_cross_entropy
train_acc_mean_list=[]
test_acc_mean_list=[]
loss_list=[]
accuracy_list=[]
best_score=0
user_embedings=[]

loss_moving_avg=[]
test_loss_list=[]
for epoch_num in range(30):
    epoch_accuracy=[]
    out_list=[]
    
    user_embedings=[]
    prob=[]
    target=[]
    for user_num,question_sequence in enumerate(users_question_sequence):
        total_loss=0
        #print(f"user id {user_num} {epoch_num}")
        question_sequence_len=int(question_sequence.shape[1]*.80)
        for  batch_num in range(lookback,question_sequence_len):

            model.train()

            optimizer.zero_grad()   
            answer=torch.tensor([question_sequence[2][batch_num]]).float()
            out,node_embeddings=model(data.x_dict, data.edge_index_dict,batch_num,lookback,question_sequence) 
            user_embedings.append((node_embeddings,answer))
            loss=F.binary_cross_entropy(out,answer)
            loss.backward(retain_graph=True)
            optimizer.step()

            loss_list.append(loss.item())
            total_loss=total_loss+loss.item()
            train_correct=out.round()==answer

            train_acc=train_correct*1
            accuracy=(train_correct*1).item()
            epoch_accuracy.append(accuracy)
            #accuracy_list.append(accuracy)
            prob.append(out.item())
            target.append(answer.item())
        print('epoch {} , batch {} '.format(epoch_num,user_num+1))
        performance='epoch {} | loss {:.5f} | accuracy {:.5f} | auc {:.5f}'.format(epoch_num,total_loss/(batch_num+1),np.mean(epoch_accuracy),roc_auc_score(np.array(target),prob))
        print(performance)
    loss_moving_avg.append(total_loss/(batch_num+1))
    test_loss=test(model)
    test_loss_list.append(test_loss)
# Out:
# epoch 0 , batch 1
# epoch 0 | loss 0.68977 | accuracy 0.53782 | auc 0.48482
# epoch 0 , batch 2
# epoch 0 | loss 0.70564 | accuracy 0.55070 | auc 0.53982
# epoch 0 , batch 3
# epoch 0 | loss 0.68523 | accuracy 0.53902 | auc 0.52809
# test_sequence_size : 91 | loss 0.6951845714024135 | accuracy 0.42857 | auc 0.50000
#
# test_sequence_size : 164 | loss 1.080310607101859 | accuracy 0.45122 | auc 0.50000
#
# test_sequence_size : 25 | loss 7.787156250476837 | accuracy 0.24000 | auc 0.50000
#
# model accuracy 0.425
#
# epoch 1 , batch 1
# epoch 1 | loss 0.68789 | accuracy 0.52381 | auc 0.43311
# epoch 1 , batch 2
# epoch 1 | loss 0.68804 | accuracy 0.53976 | auc 0.52128
# epoch 1 , batch 3
# epoch 1 | loss 0.68451 | accuracy 0.52904 | auc 0.51115
# test_sequence_size : 91 | loss 0.6948013816561017 | accuracy 0.42857 | auc 0.50000
#
# test_sequence_size : 164 | loss 1.079826616659397 | accuracy 0.45122 | auc 0.50000
#
# test_sequence_size : 25 | loss 7.782667028903961 | accuracy 0.24000 | auc 0.50000
#
# model accuracy 0.425
#
# epoch 2 , batch 1
# epoch 2 | loss 0.68782 | accuracy 0.52661 | auc 0.43403
# epoch 2 , batch 2
# epoch 2 | loss 0.68803 | accuracy 0.54076 | auc 0.52164
# epoch 2 , batch 3
# epoch 2 | loss 0.68450 | accuracy 0.52995 | auc 0.51145
# test_sequence_size : 91 | loss 0.6947997978755406 | accuracy 0.42857 | auc 0.50000
#
# test_sequence_size : 164 | loss 1.0798246184500253 | accuracy 0.45122 | auc 0.50000
#
# test_sequence_size : 25 | loss 7.782648470401764 | accuracy 0.24000 | auc 0.50000
#
# model accuracy 0.425
#
# epoch 3 , batch 1
# epoch 3 | loss 0.68782 | accuracy 0.52661 | auc 0.43400
# epoch 3 , batch 2
# epoch 3 | loss 0.68803 | accuracy 0.54076 | auc 0.52164
# epoch 3 , batch 3
# epoch 3 | loss 0.68450 | accuracy 0.52995 | auc 0.51145
# test_sequence_size : 91 | loss 0.6947995935167585 | accuracy 0.42857 | auc 0.50000
#
# test_sequence_size : 164 | loss 1.0798243371451772 | accuracy 0.45122 | auc 0.50000
#
# test_sequence_size : 25 | loss 7.782646117210388 | accuracy 0.24000 | auc 0.50000
#
# model accuracy 0.425
#
# epoch 4 , batch 1
# epoch 4 | loss 0.68782 | accuracy 0.52661 | auc 0.43400
# epoch 4 , batch 2
# epoch 4 | loss 0.68803 | accuracy 0.54076 | auc 0.52164
# epoch 4 , batch 3
# epoch 4 | loss 0.68450 | accuracy 0.52995 | auc 0.51145
# test_sequence_size : 91 | loss 0.6947996275765556 | accuracy 0.42857 | auc 0.50000
#
# test_sequence_size : 164 | loss 1.079824398203594 | accuracy 0.45122 | auc 0.50000
#
# test_sequence_size : 25 | loss 7.782646484375 | accuracy 0.24000 | auc 0.50000
#
# model accuracy 0.425
#
# epoch 5 , batch 1
# epoch 5 | loss 0.68782 | accuracy 0.52661 | auc 0.43400
# epoch 5 , batch 2
# epoch 5 | loss 0.68803 | accuracy 0.54076 | auc 0.52164
# epoch 5 , batch 3
# epoch 5 | loss 0.68450 | accuracy 0.52995 | auc 0.51145
# test_sequence_size : 91 | loss 0.6947995594569615 | accuracy 0.42857 | auc 0.50000
#
# test_sequence_size : 164 | loss 1.0798242949857944 | accuracy 0.45122 | auc 0.50000
#
# test_sequence_size : 25 | loss 7.782645716667175 | accuracy 0.24000 | auc 0.50000
#
# model accuracy 0.425
#
# epoch 6 , batch 1
# epoch 6 | loss 0.68782 | accuracy 0.52661 | auc 0.43400
# epoch 6 , batch 2
# epoch 6 | loss 0.68803 | accuracy 0.54076 | auc 0.52164
# epoch 6 , batch 3
# epoch 6 | loss 0.68450 | accuracy 0.52995 | auc 0.51145
# test_sequence_size : 91 | loss 0.6947995594569615 | accuracy 0.42857 | auc 0.50000
#
# test_sequence_size : 164 | loss 1.0798242949857944 | accuracy 0.45122 | auc 0.50000
#
# test_sequence_size : 25 | loss 7.782645716667175 | accuracy 0.24000 | auc 0.50000
#
# model accuracy 0.425
#
# epoch 7 , batch 1
# epoch 7 | loss 0.68782 | accuracy 0.52661 | auc 0.43400
# epoch 7 , batch 2
# epoch 7 | loss 0.68803 | accuracy 0.54076 | auc 0.52164
# epoch 7 , batch 3
# epoch 7 | loss 0.68450 | accuracy 0.52995 | auc 0.51145
# test_sequence_size : 91 | loss 0.6947995594569615 | accuracy 0.42857 | auc 0.50000
#
# test_sequence_size : 164 | loss 1.0798242949857944 | accuracy 0.45122 | auc 0.50000
#
# test_sequence_size : 25 | loss 7.782645716667175 | accuracy 0.24000 | auc 0.50000
#
# model accuracy 0.425
#
# epoch 8 , batch 1
# epoch 8 | loss 0.68782 | accuracy 0.52661 | auc 0.43400
# epoch 8 , batch 2
# epoch 8 | loss 0.68803 | accuracy 0.54076 | auc 0.52164
# epoch 8 , batch 3
# epoch 8 | loss 0.68450 | accuracy 0.52995 | auc 0.51145
# test_sequence_size : 91 | loss 0.6947995935167585 | accuracy 0.42857 | auc 0.50000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 52
#      50     print(performance)
#      51 loss_moving_avg.append(total_loss/(batch_num+1))
# ---> 52 test_loss=test(model)
#      53 test_loss_list.append(test_loss)
#
# Cell In[44], line 18, in test(model)
#      14 model.eval()
#      16 answer=torch.tensor([question_sequence[2][batch_num]]).float()
# ---> 18 out,node_embeddings=model(data.x_dict, data.edge_index_dict,batch_num,lookback,question_sequence)
#      19 loss=F.binary_cross_entropy(out,answer)
#      21 train_correct=out.round()==answer
#
# File ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[47], line 12, in GNN_Classifier.forward(self, x, edges, batch_num, lookback, question_sequence)
#      10 def forward(self, x,edges,batch_num,lookback,question_sequence):
#      11     #print(self.answers_weight)
# ---> 12     node_embeddings = self.model_embedding(x,edges)
#      13     features_concat_list=[]
#      15     current_lo=question_sequence[0][batch_num]
#
# File ~\Anaconda3\lib\site-packages\torch\fx\graph_module.py:652, in GraphModule.recompile.<locals>.call_wrapped(self, *args, **kwargs)
#     651 def call_wrapped(self, *args, **kwargs):
# --> 652     return self._wrapped_call(self, *args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\torch\fx\graph_module.py:267, in _WrappedCall.__call__(self, obj, *args, **kwargs)
#     265         return self.cls_call(obj, *args, **kwargs)
#     266     else:
# --> 267         return super(self.cls, obj).__call__(*args, **kwargs)  # type: ignore[misc]
#     268 except Exception as e:
#     269     assert e.__traceback__
#
# File ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File <eval_with_key>.3:20, in forward(self, x, edge_index)
#      18 actfn2__lo = self.actfn2.lo(conv2__lo);  conv2__lo = None
#      19 conv3__atom = self.conv3.lo__lo_atom__atom((actfn2__lo, actfn2__atom), edge_index__lo__lo_atom__atom);  actfn2__atom = edge_index__lo__lo_atom__atom = None
# ---> 20 conv3__lo = self.conv3.lo__lo_lo__lo(actfn2__lo, edge_index__lo__lo_lo__lo);  actfn2__lo = edge_index__lo__lo_lo__lo = None
#      21 actfn4__atom = self.actfn4.atom(conv3__atom);  conv3__atom = None
#      22 actfn4__lo = self.actfn4.lo(conv3__lo);  conv3__lo = None
#
# File ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\Anaconda3\lib\site-packages\torch_geometric\nn\conv\sage_conv.py:131, in SAGEConv.forward(self, x, edge_index, size)
#     128     x = (self.lin(x[0]).relu(), x[1])
#     130 # propagate_type: (x: OptPairTensor)
# --> 131 out = self.propagate(edge_index, x=x, size=size)
#     132 out = self.lin_l(out)
#     134 x_r = x[1]
#
# File ~\Anaconda3\lib\site-packages\torch_geometric\nn\conv\message_passing.py:459, in MessagePassing.propagate(self, edge_index, size, **kwargs)
#     456     for arg in decomp_args:
#     457         kwargs[arg] = decomp_kwargs[arg][i]
# --> 459 coll_dict = self._collect(self._user_args, edge_index, size,
#     460                           kwargs)
#     462 msg_kwargs = self.inspector.distribute('message', coll_dict)
#     463 for hook in self._message_forward_pre_hooks.values():
#
# File ~\Anaconda3\lib\site-packages\torch_geometric\nn\conv\message_passing.py:336, in MessagePassing._collect(self, args, edge_index, size, kwargs)
#     334         if isinstance(data, Tensor):
#     335             self._set_size(size, dim, data)
# --> 336             data = self._lift(data, edge_index, dim)
#     338         out[arg] = data
#     340 if is_torch_sparse_tensor(edge_index):
#
# File ~\Anaconda3\lib\site-packages\torch_geometric\nn\conv\message_passing.py:272, in MessagePassing._lift(self, src, edge_index, dim)
#     270 try:
#     271     index = edge_index[dim]
# --> 272     return src.index_select(self.node_dim, index)
#     273 except (IndexError, RuntimeError) as e:
#     274     if index.min() < 0 or index.max() >= src.size(self.node_dim):
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10,7))
mvg_steps=question_sequence_len

#for i in range(len(loss_list)-mvg_steps):
#    loss_moving_avg.append(np.mean(loss_list[mvg_steps*i:(i+1)*mvg_steps]))
plt.grid()
#plt.plot(loss_list)
plt.plot(loss_moving_avg,label='train')
plt.plot(test_loss_list,label='test')
plt.legend()

# %%
from functools import reduce

# %%
unique_questions=reduce(np.union1d, (user[1] for user in users_question_sequence))

# %%
for user in users_question_sequence:
       intersect= np.intersect1d(unique_questions,user[0])
       print(len(intersect))
# Out:
# 25

# %%
question_sequence_len=int(question_sequence.shape[1]*.8)
question_sequence_len
# Out:
# 138

# %%
question_sequence.shape[1]
# Out:
# 173

# %%
users_question_sequence[0][2].shape
# Out:
# (173,)

# %%
test(model)
# Out:
# test_sequence_size : 35 | loss 0.5692697525024414 | accuracy 0.80000 | auc 0.50000
#
# model accuracy 0.8
# 0.5692697525024414

# %%
out.item()
# Out:
# 0.6284632682800293

# %%
user_embedings[0][0].shape
# Out:
# torch.Size([100])

# %%
node_embeddings=[i[0] for i in user_embedings]

nodes=torch.stack(node_embeddings).detach().numpy()

nodesDf=pd.DataFrame(nodes[-question_sequence_len:])

pca = PCA(n_components=3)
components = pca.fit_transform(nodesDf)

#pcadf=pd.DataFrame({'f1':components[:,0],'f2':components[:,1]})
pcadf=pd.DataFrame({ 'f'+str(i):components[:,i]  for i in  range(components.shape[1]) })

answersdf=pd.DataFrame({'atom':question_sequence[1][lookback:],'answer':question_sequence[2][lookback:]})

pcadf=pcadf.reset_index().rename(columns={'index':'atom'})

answersdffea=answersdf.merge(pcadf,on='atom',how='left')

sns.pairplot(answersdffea,hue='answer')

# %%
hidden_channels=64
final_layer_dim=hidden_channels/4
class GNN_Lstm(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = SAGEConv((-1, -1), hidden_channels,requires_grad=True)
        self.actfn1=nn.ReLU()
        
        self.conv2 = SAGEConv((-1, -1),int( hidden_channels/2),requires_grad=True)
        self.actfn2=nn.ReLU()
        
        self.conv3 = SAGEConv((-1, -1),int( final_layer_dim),requires_grad=True)
        self.actfn3=nn.ReLU()
        
        self.conv4 = SAGEConv((-1, -1),int( hidden_channels/8),requires_grad=True)
        self.actfn4=nn.ReLU()
        
        
        self.sigmoid= nn.Sigmoid()

    def forward(self, x, edge_index):
        
        x = self.actfn1(self.conv1(x, edge_index))
        #x= F.dropout(x,p=.5,training=self.training)
        
        x = self.actfn2(self.conv2(x, edge_index))
        #x= F.dropout(x,p=.7,training=self.training)
        
        x = self.actfn3(self.conv3(x, edge_index))
        
        #out = self.actfn4(self.conv4(x, edge_index))
        
        #out= F.dropout(x,p=.7,training=self.training)
        #pool={key: gmp(out[key].x, out[key].batch) for key in out.node_types}
        #out=self.sigmoid( self.out(x))
        #ic(pool)
        
        #pool=gmp(out)
        return x

# %%
lookback=3
input_size=33
out_channels=1
num_layers=1
hidden_size=20
class Classifer_Lstm(nn.Module):
    
    def __init__(self ):
        super().__init__()
        self.num_layers = num_layers # number of recurrent layers in the lstm
        self.input_size = input_size # input size
        self.hidden_size = hidden_size # neurons in each lstm layer
        self.sigmoid=nn.Sigmoid()
        
        self.lstm = nn.LSTM(
            input_size=self.input_size ,
            hidden_size=self.hidden_size,
            num_layers=self.num_layers,
            batch_first=True
        )
        self.fc = nn.Linear(hidden_size, 1)
        
    def forward(self,x):
        #print(x.shape)
        h0 = torch.zeros(self.num_layers, 1, self.hidden_size).requires_grad_()
        # Initialize long-term memory
        c0 = torch.zeros(self.num_layers, 1, self.hidden_size).requires_grad_()
        # Pass all inputs to lstm layer
        out, _ = self.lstm(x, (h0, c0))
        #print(out.shape)
        out = self.sigmoid(self.fc(out[:, -1, :]))
        
        return out

# %%
class GNN_LSTM_Classifier(nn.Module):
    def __init__(self):
        super(GNN_LSTM_Classifier, self).__init__()
        
        self.model_embedding=GNN_Lstm()
        self.model_embedding = to_hetero(self.model_embedding, data.metadata(),aggr='max')
        self.classifer = Classifer_Lstm()
        #lo,atom,prev_answer,prev_lo,prev_atom,prev_answer1,prev_lo1,prev_atom1
    def forward(self, x,edges,batch_num,lookback,question_sequence):
        node_embeddings = self.model_embedding(x,edges)
        rnn_input_list=[]
        #features_concat_list=[]
        
        for i in range(lookback+1):
            
            #print([i,batch_num-i])
            lo=question_sequence[0][batch_num-i]
            atom=question_sequence[1][batch_num-i]
            prev_answer=torch.tensor([question_sequence[2][batch_num-1-i]]).float()

            features_concat=torch.cat([node_embeddings['atom'][atom],node_embeddings['lo'][lo],prev_answer])
            rnn_input_list.append(features_concat)
        
                                         
            
        #user_embeddings=torch.cat([node_embeddings['atom'][atom] , node_embeddings['lo'][lo],prev_answer,node_embeddings['atom'][prev_atom] , node_embeddings['lo'][prev_lo],prev_answer1,node_embeddings['atom'][prev_atom1] , node_embeddings['lo'][prev_lo1]])  
       
        rnn_input_stacked=torch.stack(rnn_input_list).view(1,lookback+1,features_concat.shape[0])

        rnn_outputs = self.classifer(rnn_input_stacked)
    
        return rnn_outputs,node_embeddings

# %%
training_size=sum([users_question_sequence_train_lists[i].shape[1] for i in range(len(users_question_sequence_train_lists))])

model=GNN_LSTM_Classifier()
learning_rate=0.001
optimizer=torch.optim.Adam(model.parameters(),lr=learning_rate,weight_decay=5e-12)
criterion=torch.nn.BCELoss()
#criterion=F.binary_cross_entropy
train_acc_mean_list=[]
test_acc_mean_list=[]
loss_list=[]
accuracy_list=[]
best_score=0

torch.manual_seed(42)
loss_moving_avg=[]
user_embedings=[]
for epoch_num in range(100):
    epoch_accuracy=[]
    out_list=[]
    total_loss=0
    
    prob=[]
    target=[]
    for user_num,question_sequence in enumerate(users_question_sequence_train_lists):
        question_sequence_len=question_sequence.shape[1]
        batch_loss=0
        for  batch_num in range(lookback,question_sequence_len):

            model.train()

            optimizer.zero_grad()   
            #x_dict = {key: gmp(batch[key].x, batch[key].batch) for key in batch.node_types}


            answer=torch.tensor([question_sequence[2][batch_num]]).float()


            out,node_embeddings=model(data.x_dict, data.edge_index_dict,batch_num,lookback,question_sequence) 

            loss=F.binary_cross_entropy(out.view(1),answer)
            loss.backward()
            optimizer.step()

            loss_list.append(loss.item())
            total_loss=total_loss+loss.item()
            train_correct=out.round()==answer

            train_acc=train_correct*1
            accuracy=(train_correct*1).item()
            epoch_accuracy.append(accuracy)
            #accuracy_list.append(accuracy)
            prob.append(out.item())
            target.append(answer.item())
            batch_loss=batch_loss+loss.item()
        print('epoch {} | batch {} | batch loss {:.5f}'.format(epoch_num,user_num+1,batch_loss/question_sequence_len))
    
    performance='epoch {} | loss {:.5f} | accuracy {:.5f} | auc {:.5f} \n'.format(epoch_num,total_loss/(training_size),np.mean(epoch_accuracy),roc_auc_score(np.array(target),prob))
    print('-'*len(performance))
    print(performance)
    
    loss_moving_avg.append(total_loss/(batch_num+1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 training_size=sum([users_question_sequence_train_lists[i].shape[1] for i in range(len(users_question_sequence_train_lists))])
#       3 model=GNN_LSTM_Classifier()
#       4 learning_rate=0.001
#
# NameError: name 'users_question_sequence_train_lists' is not defined

# %%
with torch.no_grad():
   
    for user_count,question_sequence in enumerate(users_question_sequence_test_lists):
            question_sequence_len=question_sequence.shape[1]
            batch_accuracy=[]
            batch_target=[]
            batch_prob=[]
            for  batch_num in range(lookback,question_sequence_len):

                model.eval()
                answer=torch.tensor([question_sequence[2][batch_num]]).float()

                out,node_embeddings=model(data.x_dict, data.edge_index_dict,batch_num,lookback,question_sequence) 

                train_correct=out.round()==answer

                train_acc=train_correct*1
                accuracy=(train_correct*1).item()
                epoch_accuracy.append(accuracy)
                prob.append(out.item())
                target.append(answer.item())
                batch_target.append(answer.item())
                batch_prob.append(out.item() )
                batch_accuracy.append(accuracy)
            batch_performance = 'test_sequence_size : {} | accuracy {:.5f} | auc {:.5f} \n'.format(question_sequence_len,np.mean(batch_accuracy),
                                                                             roc_auc_score(np.array(batch_target), batch_prob))
                
            print(batch_performance)
      
    performance='accuracy {:.5f} | auc {:.5f} \n'.format(np.mean(epoch_accuracy),roc_auc_score(np.array(target),prob))
    print('-'*len(performance))
    print(performance)

# %%
plt.figure(figsize=(10,7))
mvg_steps=question_sequence_len

#for i in range(len(loss_list)-mvg_steps):
#    loss_moving_avg.append(np.mean(loss_list[mvg_steps*i:(i+1)*mvg_steps]))
plt.grid()
#plt.plot(loss_list)
plt.plot(loss_moving_avg)

# %%
atoms=node_embeddings['atom'].detach().numpy()
pca = PCA(n_components=3)
components = pca.fit_transform(atoms)
plt.scatter(components[:,0],components[:,1])

# %%
los=node_embeddings['lo'].detach().numpy()
pca = PCA(n_components=3)
components1 = pca.fit_transform(los)

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.axes(projection='3d')

ax.scatter(components[:,0], components[:,1], components[:,2]);
ax.scatter(components1[:,0], components1[:,1], components1[:,2] );

# %%
seq_features=[]
for i in range(3,question_sequence_len):
    seq_features.append(torch.cat([node_embeddings['atom'][question_sequence[1][i]].detach(),
                                   #node_embeddings['lo'][question_sequence[0][i]].detach(),
                                   #torch.tensor([question_sequence[-1][i-1]]),
                                   
                                    node_embeddings['atom'][question_sequence[1][i-1]].detach(),
                                   #node_embeddings['lo'][question_sequence[0][i-1]].detach(),
                                   #torch.tensor([question_sequence[-1][i-2]]),
                                   
                                    node_embeddings['atom'][question_sequence[1][i-2]].detach(),
                                   #node_embeddings['lo'][question_sequence[0][i-2]].detach(),
                                   #torch.tensor([question_sequence[-1][i-3]])
                                  
                                  
                                  ]).numpy())

# %%
#first_user_sq_length=dfg[dfg.user_id==dfg.user_id.unique()[0]].shape[0]
first_user_sq_length=0
second_user_sq_length=dfg[dfg.user_id==dfg.user_id.unique()[1]].shape[0]

# %%
np.stack(seq_features ).shape

# %%
pca = PCA(n_components=3)
components2 = pca.fit_transform(np.stack(seq_features ) )
                            #[first_user_sq_length:first_user_sq_length+second_user_sq_length])

# %%
question_sequence[-1][3:first_user_sq_length+3].shape

# %%
components2.shape

# %%
pcadf=pd.DataFrame({ 'f'+str(i):components2[:,i]  for i in  range(components2.shape[1]) })


pcadf['answers']=question_sequence[-1][3:second_user_sq_length+3]

# %%
   
sns.pairplot(pcadf,hue='answers')
plt.show()

# %%
from matplotlib.animation import FFMpegWriter, PillowWriter

# %%
metadata = dict( artist='codinglikemad')
# writer = PillowWriter(fps=15, metadata=metadata)
writer = FFMpegWriter(fps=10, metadata=metadata)

# %%
plt.rcParams['animation.ffmpeg_path'] = "C:\\research\\ffmpeg-4.4-full_build\\bin\\ffmpeg.exe"

# %%
fig = plt.figure(figsize=(100,100))
ax = plt.axes(projection='3d')
correct=pcadf[pcadf.answers==1]
falls=pcadf[pcadf.answers==0]
#ax.set_xlabel('f0')
#ax.set_ylabel('f1')
#ax.set_zlabel('f2')
#ax.scatter3D(correct.iloc[:,1], correct.iloc[:,2], correct.iloc[:,0],label='correct');
#ax.scatter3D(falls.iloc[:,1], falls.iloc[:,2], falls.iloc[:,0],label='wrong');
#plt.legend()
S=2500
angle1=30
with writer.saving(fig, "exp3d.gif", 10):
    for i in tqdm(range(0,720,2)):
        
        ax.set_xlabel('f0',fontsize=100)
        ax.set_ylabel('f1',fontsize=100)
        ax.set_zlabel('f2',fontsize=100)
        ax.scatter3D(correct.iloc[:,1], correct.iloc[:,2], correct.iloc[:,0],label='correct',s=S);
        ax.scatter3D(falls.iloc[:,1], falls.iloc[:,2], falls.iloc[:,0],label='wrong',s=S);
        plt.legend(markerscale=2,fontsize=100)
        
        ax.view_init(45, i);

        writer.grab_frame()
        plt.cla()

# %%
#fig = plt.figure()

def animate(angle):
    ax.view_init(30, angle)
#animate(10)
fig = plt.figure(figsize=(15,15))
ax = plt.axes(projection='3d')
correct=pcadf[pcadf.answers==1]
falls=pcadf[pcadf.answers==0]
   
for i in range(1,360,72):
    ax.set_xlabel('f0')
    ax.set_ylabel('f1')
    ax.set_zlabel('f2') 
    ax.scatter3D(correct.iloc[:,1], correct.iloc[:,2], correct.iloc[:,0],label='correct');
    ax.scatter3D(falls.iloc[:,1], falls.iloc[:,2], falls.iloc[:,0],label='wrong');
    #plt.legend()
    ax.view_init(i, 0);
    #ax.draw();
    plt.pause(.001);
    ax.cla()
#ani = FuncAnimation(fig, animate, frames=range(360))

# %%
animate(20)

# %%
falls.mean()
